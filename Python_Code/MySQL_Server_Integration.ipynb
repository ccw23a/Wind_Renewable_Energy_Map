# %%
import pymysql

# %%
db = pymysql.connect(
    host='192.168.56.23',
    port = 3306,
    user='ccw23a',
    password='ccw23a'
    db='test',
    charset='utf8'
)

# %% [markdown]
# Now could load DB with ease now
